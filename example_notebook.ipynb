# %% [markdown]
# # Example Test Notebook
#
# This is a simple test notebook to verify the leaderboard system works.
#
# ## Instructions for Students
#
# 1. Solve the problems below
# 2. Run all cells to verify they work
# 3. Submit this notebook to the leaderboard

# %% [markdown]
# ## Problem 1: Simple Calculations
#
# Calculate the sum of numbers from 1 to 100

# %%
# Calculate sum of 1 to 100
result = sum(range(1, 101))
print(f"Sum of 1 to 100: {result}")

# %% [markdown]
# ## Problem 2: Generate a List
#
# Create a list of squares from 1 to 10

# %%
# Create list of squares
squares = [i**2 for i in range(1, 11)]
print(f"Squares: {squares}")

# %% [markdown]
# ## Problem 3: String Manipulation
#
# Reverse a string

# %%
# Reverse a string
text = "Hello World"
reversed_text = text[::-1]
print(f"Original: {text}")
print(f"Reversed: {reversed_text}")

# %% [markdown]
# ## Completion
#
# This notebook demonstrates basic Python operations that can be executed and scored by the leaderboard system.
